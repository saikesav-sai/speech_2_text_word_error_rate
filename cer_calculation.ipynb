# %%
import os
import pandas as pd

# %%
def calculate_cer(reference, hypothesis):
    """
    Calculate Character Error Rate (CER) between reference and hypothesis strings.
    CER is the percentage of characters that are incorrect in the hypothesis compared to the reference.
    """
    reference = reference.lower()
    hypothesis = hypothesis.lower()

    # Create a matrix to store the distances between substrings
    dp = [[0] * (len(hypothesis) + 1) for _ in range(len(reference) + 1)]

    for i in range(len(reference) + 1):
        for j in range(len(hypothesis) + 1):
            if i == 0:
                dp[i][j] = j
            elif j == 0:
                dp[i][j] = i
            elif reference[i - 1] == hypothesis[j - 1]:
                dp[i][j] = dp[i - 1][j - 1]
            else:
                dp[i][j] = 1 + min(dp[i][j - 1],      # Insert
                                   dp[i - 1][j],      # Remove
                                   dp[i - 1][j - 1])  # Replace

    # Calculate CER as the normalized edit distance
    cer = dp[len(reference)][len(hypothesis)] / len(reference)
    return cer

# %%
input_directory = r"..\outputs\libri_dataset_outputs\noise_word_vec\without_group"


# Iterate through all CSV files in the directory
for filename in os.listdir(input_directory):
    if filename.endswith('.csv'):
        file_path = os.path.join(input_directory, filename)
        
        # Try different encodings if utf-8 fails
        encodings = ['utf-8', 'latin1', 'ISO-8859-1']
        for encoding in encodings:
            try:
                df = pd.read_csv(file_path, encoding=encoding)
                break
            except UnicodeDecodeError:
                print(f"Failed to decode {filename} with {encoding} encoding.")
        else:
            print(f"Unable to decode {filename} with any of the provided encodings.")
            continue

        # Add a new column for CER
        df['CER'] = df.apply(lambda row: calculate_cer(str(row['Expected Text']), str(row['Generated Text'])), axis=1)

        # Save the updated dataframe to a new CSV file
        output_file_path = os.path.join(input_directory, f'{filename}')
        df.to_csv(output_file_path, index=False)

        print(f"CER calculation completed and saved to '{output_file_path}'")
# Out:
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1089-134686.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1089-134691.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1188-133604.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\121-121726.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\121-123852.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\121-123859.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\121-127105.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1221-135766.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1221-135767.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1284-1180.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1284-1181.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1284-134647.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1320-122612.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1320-122617.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1580-141083.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1580-141084.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1995-1826.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1995-1836.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\1995-1837.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\2094-142345.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\2300-131720.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\237-126133.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\237-134493.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\237-134500.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\260-123286.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\260-123288.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\260-123440.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\2830-3979.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\2830-3980.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\2961-960.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\2961-961.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\3570-5694.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\3570-5695.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\3570-5696.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\3575-170457.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\3729-6852.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\4077-13751.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\4077-13754.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\4446-2271.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\4446-2273.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\4446-2275.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\4507-16021.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\4970-29093.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\4970-29095.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\4992-23283.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\4992-41797.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\4992-41806.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\5105-28233.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\5105-28240.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\5105-28241.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\5142-33396.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\5142-36377.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\5142-36586.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\5142-36600.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\5639-40744.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\5683-32865.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\5683-32866.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\5683-32879.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\61-70968.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\61-70970.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\672-122797.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\6829-68769.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\6829-68771.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\6930-75918.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\6930-76324.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\6930-81414.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\7021-79730.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\7021-79740.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\7021-79759.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\7021-85628.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\7127-75946.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\7127-75947.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\7176-88083.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\7176-92135.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\7729-102255.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\8224-274381.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\8224-274384.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\8230-279154.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\8455-210777.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\8463-287645.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\8463-294825.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\8463-294828.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\8555-284447.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\8555-284449.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\8555-292519.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\908-157963.csv'
# CER calculation completed and saved to '..\outputs\libri_dataset_outputs\noise_word_vec\without_group\908-31957.csv'
